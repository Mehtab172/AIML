# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %% [markdown]
# # Load Dataset

# %%
X_train = np.loadtxt("C:/Users/mehta/Downloads/input.csv", delimiter = ',')
Y_train = np.loadtxt("C:/Users/mehta/Downloads/labels.csv", delimiter = ',')

X_test = np.loadtxt("C:/Users/mehta/Downloads/input_test.csv", delimiter = ',')
Y_test = np.loadtxt("C:/Users/mehta/Downloads/labels_test.csv", delimiter = ',')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 X_train = np.loadtxt("C:/Users/mehta/Downloads/input.csv", delimiter = ',')
#       2 Y_train = np.loadtxt("C:/Users/mehta/Downloads/labels.csv", delimiter = ',')
#       4 X_test = np.loadtxt("C:/Users/mehta/Downloads/input_test.csv", delimiter = ',')
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
# ...

# %%
X_train = X_train.reshape(len(X_train), 100, 100, 3)
Y_train = Y_train.reshape(len(Y_train), 1)

X_test = X_test.reshape(len(X_test), 100, 100, 3)
Y_test = Y_test.reshape(len(Y_test), 1)

X_train = X_train/255.0
X_test = X_test/255.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 X_train = X_train.reshape(len(X_train), 100, 100, 3)
#       2 Y_train = Y_train.reshape(len(Y_train), 1)
#       4 X_test = X_test.reshape(len(X_test), 100, 100, 3)
#
# NameError: name 'X_train' is not defined
