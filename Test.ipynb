# %%
import pandas as pd
import numpy as np 
df=pd.read_csv("C:/Users/mehta/AIML PRACTICES/DataSets/Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           NaN            1.5           0.2
# 4      5            5.0           3.6            NaN           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # 1

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     3
# PetalLengthCm    1
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
m=df['SepalWidthCm'].mean()
df['SepalWidthCm']=df['SepalWidthCm'].fillna(m)

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    1
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df['SepalWidthCm'].plot(kind='box')
plt.show()

# %%
q1=df['SepalWidthCm'].quantile(0.25)
q3=df['SepalWidthCm'].quantile(0.75)
iqr=q3-q1
upper_bound=q1+(1.5*iqr)
lower_bound=q3-(1.5*iqr)

upper_cap=np.percentile(df['SepalWidthCm'],99)
lower_cap=np.percentile(df['SepalWidthCm'],1)

# %%
m=df['SepalWidthCm'].mean()
print(m)
# Out:
# 3.048979591836735

# %%
for i in df['SepalWidthCm']:
    if i<lower_bound or i>upper_bound:
        df['SepalWidthCm']=df['SepalWidthCm'].replace(i,m)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df['SepalLengthCm'].plot(kind='box')
plt.show()

# %%
q1=df['SepalLengthCm'].quantile(0.25)
q3=df['SepalLengthCm'].quantile(0.75)
iqr=q3-q1
upper_bound=q1+(1.5*iqr)
lower_bound=q3-(1.5*iqr)

upper_cap=np.percentile(df['SepalLengthCm'],99)
lower_cap=np.percentile(df['SepalLengthCm'],1)

# %%
m=df['SepalLengthCm'].mean()
print(m)
for i in df['SepalLengthCm']:
    if i<lower_bound or i>upper_bound:
        df['SepalLengthCm']=df['SepalLengthCm'].replace(i,m)
# Out:
# 5.843333333333334

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 3

# %%
plt.hist(df['SepalLengthCm'])
plt.show()
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\mehta\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df['SepalLengthCm'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # 4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
count=df['Species'].value_counts()
plt.bar(count.index,count.values)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# # 5

# %%
df['Final id']=df['Id']
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1       3.50000            1.4           0.2
# 1      2            4.9       3.00000            1.4           0.2
# 2      3            4.7       3.20000            1.3           0.2
# 3      4            4.6       3.04898            1.5           0.2
# 4      5            5.0       3.04898            NaN           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7       3.00000            5.2           2.3
# 146  147            6.3       3.04898            5.0           1.9
# 147  148            6.5       3.00000            5.2           2.0
# 148  149            6.2       3.40000            5.4           2.3
# 149  150            5.9       3.00000            5.1           1.8
#
#             Species  Final id
# 0       Iris-setosa         1
# 1       Iris-setosa         2
# 2       Iris-setosa         3
# 3       Iris-setosa         4
# ...

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7       3.00000            5.2           2.3
# 146  147            6.3       3.04898            5.0           1.9
# 147  148            6.5       3.00000            5.2           2.0
# 148  149            6.2       3.40000            5.4           2.3
# 149  150            5.9       3.00000            5.1           1.8
#
#             Species  Final id
# 145  Iris-virginica       146
# 146  Iris-virginica       147
# 147  Iris-virginica       148
# 148  Iris-virginica       149
# 149  Iris-virginica       150

# %%
df.loc[len(df.index)]=[50,1.252556,3.556893,1.6,3.5,'setosa',2]
df.loc[len(df.index)]=[580,3.252556,85.556893,6.6,5.5,'virginica',50]
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 147  148       6.500000      3.000000            5.2           2.0
# 148  149       6.200000      3.400000            5.4           2.3
# 149  150       5.900000      3.000000            5.1           1.8
# 150   50       1.252556      3.556893            1.6           3.5
# 151  580       3.252556     85.556893            6.6           5.5
#
#             Species  Final id
# 147  Iris-virginica       148
# 148  Iris-virginica       149
# 149  Iris-virginica       150
# 150          setosa         2
# 151       virginica        50

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/mehta/AIML PRACTICES/DataSets/titanic.csv")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# # to drop a column

# %%
df=df.drop('embark_town',axis=1)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck alive  alone
# ...

# %%
df=df.drop([0,1],inplace=True)
df

# %%
df.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df.dropna(inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'dropna'

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df.isnull().sum()
#
# AttributeError: 'NoneType' object has no attribute 'isnull'

# %%
plt.boxplot(df['fare'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 plt.boxplot(df['fare'])
#       2 plt.show()
#
# TypeError: 'NoneType' object is not subscriptable
