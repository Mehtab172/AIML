# %%
import tensorflow as tf
import numpy as np 
import matplotlib.pyplot as plt
from tensorflow import keras 
from sklearn import metrics

# %%
(x_train,y_train),(x_test,y_test)=keras.datasets.mnist.load_data()

# %%
len(x_train)
# Out:
# 60000

# %%
len(x_test)
# Out:
# 10000

# %%
x_train[0].shape
# Out:
# (28, 28)

# %%
plt.matshow(x_train[0])
plt.show()

# %%
y_train[0]
# Out:
# np.uint8(5)

# %%
x_train=x_train/255
x_test=x_test/255

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_train_flattent=x_train.reshape(len(x_train),28*28)
x_test_flattent=x_test.reshape(len(x_test),28*28)

# %%
x_train_flattent.shape
# Out:
# (60000, 784)

# %%
model=keras.Sequential([keras.layers.Dense(10,input_shape=(784,),activation='sigmoid')])
# Out:
# C:\Users\mehta\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train_flattent, y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8749 - loss: 0.4732
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9151 - loss: 0.3040
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9207 - loss: 0.2832
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9233 - loss: 0.2734
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9254 - loss: 0.2668

# %%
model.evaluate(x_test_flattent,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9253 - loss: 0.2712
# [0.2712435722351074, 0.9253000020980835]

# %%
y_predict=model.predict(x_test_flattent)
y_predict[0]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# array([2.5308644e-02, 3.4149920e-07, 5.2833226e-02, 9.6464562e-01,
#        1.9429484e-03, 1.5229659e-01, 1.9369297e-06, 9.9979085e-01,
#        8.4747583e-02, 5.7580924e-01], dtype=float32)

# %%
plt.matshow(x_test[0])

# %%
np.argmax(y_predict[0])
# Out:
# np.int64(7)

# %%
y_predict_labels=[np.argmax(i) for i in y_predict]

# %%
y_predict_labels[:5]
# Out:
# [np.int64(7), np.int64(2), np.int64(1), np.int64(0), np.int64(4)]

# %%
print("classification report : \n",metrics.classification_report(y_test,y_predict_labels))
# Out:
# classification report :
#                precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       980
#            1       0.97      0.98      0.97      1135
#            2       0.95      0.88      0.92      1032
#            3       0.89      0.93      0.91      1010
#            4       0.93      0.94      0.93       982
#            5       0.92      0.87      0.89       892
#            6       0.93      0.96      0.94       958
#            7       0.93      0.93      0.93      1028
#            8       0.87      0.89      0.88       974
#            9       0.92      0.90      0.91      1009
#
#     accuracy                           0.93     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.93      0.93      0.93     10000

# %%
print("confusion metrics",metrics.confusion_matrix(y_test,y_predict_labels))
# Out:
# confusion metrics [[ 963    0    0    2    0    4    8    2    1    0]
#  [   0 1108    3    2    0    1    4    2   15    0]
#  [   9    9  913   21    8    4   13   11   40    4]
#  [   4    0   12  935    0   21    2   11   18    7]
#  [   2    1    2    2  919    0   15    4   10   27]
#  [  11    2    2   37    8  773   17    5   31    6]
#  [  14    3    3    2    7    9  917    2    1    0]
#  [   2    5   21    8    5    0    0  955    2   30]
#  [  11    6    6   28    9   26    9   11  862    6]
#  [  11    7    1   14   31    6    0   25    6  908]]
