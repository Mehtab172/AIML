# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error

# %%
df = pd.read_csv("C:/Users/mehta/AIML-20CS51I/DataSets/laptop_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
import seaborn as sns

# %%
plt.hist(df['Price'])
# Out:
# (array([474., 448., 231.,  98.,  37.,   8.,   3.,   2.,   1.,   1.]),
#  array([  9270.72,  40839.12,  72407.52, 103975.92, 135544.32, 167112.72,
#         198681.12, 230249.52, 261817.92, 293386.32, 324954.72]),
#  <BarContainer object of 10 artists>)

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
plt.bar(df['Company'],df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.hist(df['Inches'])
# Out:
# (array([  4.,  34.,  50., 166., 210.,   4., 669.,   0., 165.,   1.]),
#  array([10.1 , 10.93, 11.76, 12.59, 13.42, 14.25, 15.08, 15.91, 16.74,
#         17.57, 18.4 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(5)
# Out:
#     Company            TypeName  Inches  \
# 232  Lenovo              Gaming    15.6
# 81    Apple           Ultrabook    12.0
# 219    Dell  2 in 1 Convertible    13.3
# 443  Lenovo            Notebook    15.6
# 470      HP  2 in 1 Convertible    13.3
#
#                                   ScreenResolution  \
# 232                    IPS Panel Full HD 1920x1080
# 81              IPS Panel Retina Display 2304x1440
# 219                Full HD / Touchscreen 1920x1080
# 443                              Full HD 1920x1080
# 470  IPS Panel 4K Ultra HD / Touchscreen 3840x2160
#
#                                       Cpu  Ram                Memory  \
# 232           Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 81                   Intel Core i5 1.3GHz    8             512GB SSD
# 219            Intel Core i7 8550U 1.8GHz   16             512GB SSD
# 443  Intel Pentium Quad Core N4200 1.1GHz    4             128GB SSD
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ips'>

# %%
sns.barplot(x=df['Ips'],y=df['Price'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.sample(5)
# Out:
#     Company            TypeName  Inches  \
# 346      HP            Notebook    14.0
# 65     Asus           Ultrabook    15.6
# 182  Lenovo  2 in 1 Convertible    13.9
# 752    Asus            Notebook    15.6
# 625  Lenovo            Notebook    15.6
#
#                                   ScreenResolution  \
# 346                                       1366x768
# 65                               Full HD 1920x1080
# 182  IPS Panel 4K Ultra HD / Touchscreen 3840x2160
# 752                                       1366x768
# 625                              Full HD 1920x1080
#
#                                       Cpu  Ram              Memory  \
# 346  Intel Celeron Dual Core N3060 1.6GHz    2  32GB Flash Storage
# 65            Intel Core i7 7700HQ 2.8GHz   16           512GB SSD
# 182            Intel Core i7 8550U 1.8GHz   16           512GB SSD
# 752           Intel Core i5 6300HQ 2.3GHz    4             1TB HDD
# 625            Intel Core i7 7500U 2.7GHz    8             1TB HDD
#
# ...

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   object
#  14  Y_res             1303 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# ...

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
aaaaaaaaa
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips  X_res  Y_res
# 0   71378.6832            0    1   2560   1600
# 1   47895.5232            0    0   1440    900
# ...

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
X= df.drop(columns=['Price'])
y =df['Price']

# %%
X
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1298  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1299  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1300  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1301      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
# 1302    Asus            Notebook  Intel Celeron Dual Core N3050 1.6GHz    4
#
# ...

# %%
y
# Out:
# 0        71378.6832
# 1        47895.5232
# 2        30636.0000
# 3       135195.3360
# 4        96095.8080
#            ...
# 1298     33992.6400
# 1299     79866.7200
# 1300     12201.1200
# 1301     40705.9200
# 1302     19660.3200
# Name: Price, Length: 1303, dtype: float64

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=45)

# %%
X_train
# Out:
#       Ram  Weight  Touchscreen  Ips  Company_Apple  Company_Asus  \
# 547     4    2.15            0    0          False         False
# 710     8    2.50            0    1          False         False
# 1136    8    3.00            0    1          False         False
# 909     8    0.98            1    1          False         False
# 724     8    2.70            0    0          False         False
# ...   ...     ...          ...  ...            ...           ...
# 580     4    1.45            0    1          False         False
# 163    16    2.50            0    1          False         False
# 607     6    2.40            0    0          False         False
# 414     8    1.27            1    1          False          True
# 971     8    1.50            1    0          False         False
#
#       Company_Chuwi  Company_Dell  Company_Fujitsu  Company_Google  ...  \
# 547           False         False            False           False  ...
# ...

# %%
y_test
# Out:
# 731      34578.7200
# 815      99047.5200
# 666      50882.4000
# 538      95850.7200
# 1166     74059.2000
#            ...
# 652      77250.6720
# 924      97236.0000
# 579      39907.2528
# 265      42570.7200
# 1054    120093.1200
# Name: Price, Length: 261, dtype: float64

# %%
lr = LinearRegression()
model = lr.fit(X_train,y_train)

# %%
y_pred = model.predict(X_test)

# %%
df = pd.DataFrame({'y_test':y_test,'y_pred':y_pred})
df
# Out:
#            y_test         y_pred
# 731    34578.7200   51413.509118
# 815    99047.5200   76612.315433
# 666    50882.4000   45835.249387
# 538    95850.7200   80306.379123
# 1166   74059.2000   54246.847293
# ...           ...            ...
# 652    77250.6720   69481.853898
# 924    97236.0000   80809.569589
# 579    39907.2528   45379.745091
# 265    42570.7200   62018.946512
# 1054  120093.1200  144818.798851
#
# [261 rows x 2 columns]

# %%
mse = mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)

# %%
print("Root Mean Square Error",rmse)
print("The R2 score is : ", r2_score(y_test, y_pred))
print("Mean Absolute Error:",mean_absolute_error(y_test,y_pred))
# Out:
# Root Mean Square Error 21986.29057042682
# The R2 score is :  0.6373501043203416
# Mean Absolute Error: 13532.703015531602

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder 

# ✅ Take user input
brand = input("Enter Laptop Brand (e.g., Dell, HP, Lenovo): ")
processor = input("Enter Processor (e.g., i5, i7, Ryzen 5): ")
ram = int(input("Enter RAM (GB): "))
storage = int(input("Enter Storage (GB): "))
gpu = input("Graphic Card (Yes/No): ")

# Put into DataFrame with same column names as training
new_laptop = pd.DataFrame({
    "Brand": [brand],
    "Processor": [processor],
    "RAM (GB)": [ram],
    "Storage (GB)": [storage],
    "Graphic Card (Yes/No)": [gpu]
})
brand_encoder = LabelEncoder()
processor_encoder = LabelEncoder()
gpu_encoder = LabelEncoder()


# ⚠️ Apply the SAME encoding you used during training
# Example: if you used LabelEncoders for categorical columns
new_laptop["Brand"] = brand_encoder.transform(new_laptop["Brand"])
new_laptop["Processor"] = processor_encoder.transform(new_laptop["Processor"])
new_laptop["Graphic Card (Yes/No)"] = gpu_encoder.transform(new_laptop["Graphic Card (Yes/No)"])

X = df[["Brand", "Processor", "RAM (GB)", "Storage (GB)", "Graphic Card (Yes/No)"]]
y = df["Price"]

model.fit(X, y)

# ✅ Predict Price
predicted_price = model.predict(new_laptop)
print("\n💻 Predicted Laptop Price:", round(predicted_price[0], 2))
# Out:
# Enter Laptop Brand (e.g., Dell, HP, Lenovo):  HP
# Enter Processor (e.g., i5, i7, Ryzen 5):  i7
# Enter RAM (GB):  8
# Enter Storage (GB):  256
# Graphic Card (Yes/No):  yes
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[7], line 27
#      22 gpu_encoder = LabelEncoder()
#      25 # ⚠️ Apply the SAME encoding you used during training
#      26 # Example: if you used LabelEncoders for categorical columns
# ---> 27 new_laptop["Brand"] = brand_encoder.transform(new_laptop["Brand"])
#      28 new_laptop["Processor"] = processor_encoder.transform(new_laptop["Processor"])
#      29 new_laptop["Graphic Card (Yes/No)"] = gpu_encoder.transform(new_laptop["Graphic Card (Yes/No)"])
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:127, in LabelEncoder.transform(self, y)
#     114 def transform(self, y):
# ...
