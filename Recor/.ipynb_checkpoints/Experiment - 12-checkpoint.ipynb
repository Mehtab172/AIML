# %% [markdown]
# # -------------------------------Experiment - 12------------------------------------

# %% [markdown]
# # Consider the Mnist dataset preprocess and built simple Sequential neural network on it. Test and evaluete the model using different metrics.

# %%
# import the libraies 

import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# %%
# Optional: to ignore warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Load the dataset 

(X_train, y_train) , (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
# Length 

len(X_train)
# Out:
# 60000

# %%
len(X_test)
# Out:
# 10000

# %%
X_train[0].shape
# Out:
# (28, 28)

# %%
# plot the 

plt.matshow(X_train[0])
plt.show()

# %%
y_train[0]
# Out:
# 5

# %%
#

X_train = X_train / 255
X_test = X_test / 255

# %%
# Reshape the 

X_train_flattened = X_train.reshape(len(X_train), 28*28)
X_test_flattened = X_test.reshape(len(X_test), 28*28)

# %%
X_train_flattened.shape
# Out:
# (60000, 784)

# %%
# Fit the model 

model = keras.Sequential([
    keras.layers.Dense(10, input_shape=(784,), activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8757 - loss: 0.4728
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9144 - loss: 0.3042
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9200 - loss: 0.2836
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9241 - loss: 0.2730
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9255 - loss: 0.2663

# %%
# Evaluate the model 

model.evaluate(X_test_flattened, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9256 - loss: 0.2704
# [0.27039819955825806, 0.925599992275238]

# %%
# Predict the model

y_predicted = model.predict(X_test_flattened)
y_predicted[0]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# array([2.7477549e-02, 3.6950368e-07, 3.9902255e-02, 9.3148303e-01,
#        2.2428508e-03, 9.8713197e-02, 1.1547515e-06, 9.9964052e-01,
#        8.9514740e-02, 6.6582799e-01], dtype=float32)

# %%
# Show the predict plot 

plt.matshow(X_test[0])

# %%
np.argmax(y_predicted[0])
# Out:
# 7

# %%
y_predicted_labels = [np.argmax(i) for i in y_predicted]

# %%
y_predicted_labels[:5]
# Out:
# [7, 2, 1, 0, 4]

# %%
print("Classification Report:\n", classification_report(y_test, y_predicted_labels))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       980
#            1       0.97      0.98      0.97      1135
#            2       0.94      0.88      0.91      1032
#            3       0.93      0.90      0.91      1010
#            4       0.92      0.93      0.93       982
#            5       0.91      0.88      0.89       892
#            6       0.93      0.96      0.95       958
#            7       0.95      0.91      0.93      1028
#            8       0.88      0.89      0.88       974
#            9       0.89      0.93      0.91      1009
#
#     accuracy                           0.93     10000
#    macro avg       0.93      0.92      0.92     10000
# weighted avg       0.93      0.93      0.93     10000

# %%
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_predicted_labels)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 964,    0,    0,    2,    0,    4,    7,    2,    1,    0],
#        [   0, 1112,    3,    2,    0,    1,    4,    2,   11,    0],
#        [   8,   11,  913,   16,   14,    4,   13,   10,   39,    4],
#        [   5,    0,   16,  907,    1,   34,    3,    9,   23,   12],
#        [   2,    1,    2,    1,  917,    0,   10,    3,    8,   38],
#        [  11,    3,    2,   18,   11,  784,   20,    4,   32,    7],
#        [  12,    3,    3,    1,    7,    7,  921,    2,    2,    0],
#        [   1,    6,   21,    7,   11,    0,    0,  933,    3,   46],
#        [  10,    9,    6,   15,    9,   23,   10,    8,  870,   14],
#        [  12,    7,    1,    8,   27,    6,    0,    8,    5,  935]])>

# %%
# Show the heat map 

import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()
