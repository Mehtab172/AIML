# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/mehta/AIML-20CS51I/DataSets/titanic.csv")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['age'].plot(kind='box')
plt.show()

# %% [markdown]
# #  Remove Outliers (IQR Method)

# %%
# finding the 1st quartile
q1 = df["age"].quantile(0.25)

# finding the 3rd quartile
q3 = df['age'].quantile(0.75)

# finding the iqr region
iqr = q3-q1

# finding upper and lower whiskers
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)

# %%
df_iqr = df[(df['age'] >= lower_bound) & (df['age'] <= upper_bound)]

# %%
df_iqr['age'].plot(kind='box')
plt.show()

# %% [markdown]
# #  Replace Outliers using Upper Cap and Lower Cap

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/mehta/AIML-20CS51I/DataSets/titanic.csv")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['age'].plot(kind='box')
plt.show()

# %%
age_arr = df["age"]
lower_cap = np.percentile(age_arr,1)
upper_cap = np.percentile(age_arr,99)

# %%
for i in df['age']:
    if i<lower_bound :
        df['age'] = df['age'].replace(i,lower_cap)
    elif i>upper_bound :
        df['age'] = df['age'].replace(i,upper_cap)

# %% [markdown]
# # OR

# %%
df['age'] = np.where(df['age'] < lower_bound, lower_bound,
              np.where(df['age'] > upper_bound, upper_bound, df['age']))

# %%
df['age'].plot(kind='box')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/mehta/AIML-20CS51I/DataSets/titanic.csv")

# %% [markdown]
# #  Replace Outliers with Mean

# %%
df['age'].plot(kind='box')
plt.show()

# %%
import numpy as np

m = df['age'].mean()
df['age'] = np.where((df['age'] < lower_bound) & (df['age'] > upper_bound),  m,  df['age'])

# %%
df['age'].plot(kind='box')
plt.show()

# %% [markdown]
# #  Replace Outliers with Median

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/mehta/AIML-20CS51I/DataSets/titanic.csv")

# %%
df['age'].plot(kind='box')
plt.show()

# %%
import numpy as np

m = df['age'].median()
df['age'] = np.where((df['age'] < lower_bound) | (df['age'] > upper_bound),  m,  df['age'])

# %%
df['age'].plot(kind='box')
plt.show()
