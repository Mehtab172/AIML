# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/mehta/AIML PRACTICES/DataSets/Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           NaN            1.5           0.2
# 4      5            5.0           3.6            NaN           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    147.000000     149.000000    150.000000
# mean    75.500000       5.843333      3.048980       3.774497      1.198667
# std     43.445368       0.828066      0.436105       1.759651      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.400000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.shape
# Out:
# (150, 6)

# %%
count=df['Species'].value_counts()
count.plot(kind='bar')
# Out:
# <Axes: xlabel='Species'>

# %%
plt.hist(df['PetalLengthCm'])
plt.show()

# %%
sp_list=df['Species'].unique()
colors=['red','green','blue']
for species, color in zip(sp_list,colors):
    subset=df[df['Species']==species]
    plt.scatter(subset['PetalLengthCm'],subset['SepalWidthCm'],label=species,color=color)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/mehta/AIML PRACTICES/DataSets/rainfall.csv")
df
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY  \
# 0     Andaman & Nicobar Islands  1901  49.2   87.1   29.2    2.3  528.8
# 1     Andaman & Nicobar Islands  1902   0.0  159.8   12.2    0.0  446.1
# 2     Andaman & Nicobar Islands  1903  12.7  144.0    0.0    1.0  235.1
# 3     Andaman & Nicobar Islands  1904   9.4   14.7    0.0  202.4  304.5
# 4     Andaman & Nicobar Islands  1905   1.3    0.0    3.3   26.9  279.5
# ...                         ...   ...   ...    ...    ...    ...    ...
# 4183                Lakshadweep  2013  26.2   34.4   37.5    5.3   88.3
# 4184                Lakshadweep  2014  53.2   16.1    4.4   14.9   57.4
# 4185                Lakshadweep  2015   2.2    0.5    3.7   87.1  133.1
# 4186                Lakshadweep  2016  59.6   12.1    3.2    2.6   77.4
# 4187                Lakshadweep  2017  21.3    0.9  100.2    1.8  145.7
#
#         JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL     JF    MAM  \
# ...
