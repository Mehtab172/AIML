# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/mehta/Desktop/AIML Study Materials/AIML-20CS51I/DataSets/titanic.csv")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df[df['age'].notna()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.shape
# Out:
# (891, 15)

# %%
df['embarked']=df['embarked'].fillna(C)
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
mean=df['age'].mean()
df['age']=df['age'].fillna(mean)
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
C=df['deck'].mode()[0]
df['deck']=df['deck'].fillna(C)
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
mode=df['deck'].mode()[0]
mode
# Out:
# 'C'

# %%
mode=df['embark_town'].mode()[0]
df['embark_town']=df['embark_town'].fillna(mode)
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df['alone']=df['alone'].apply(lambda x:0 if x=='False' else 1)
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      2      0   7.2500        S  Third
# 1         1       1  female  38.0      2      0  71.2833        C  First
# 2         1       3  female  26.0      2      0   7.9250        S  Third
# 3         1       1  female  35.0      2      0  53.1000        S  First
# 4         0       3    male  35.0      2      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town  alive  alone
# 0    man        True  NaN  Southampton      1      1
# 1  woman       False    C    Cherbourg      1      1
# 2  woman       False  NaN  Southampton      1      1
# 3  woman       False    C  Southampton      1      1
# 4    man        True  NaN  Southampton      1      1

# %%
df['new_fare']=df['fare']+10
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  new_fare
# 0    man        True  NaN  Southampton    no  False   17.2500
# 1  woman       False    C    Cherbourg   yes  False   81.2833
# 2  woman       False  NaN  Southampton   yes   True   17.9250
# 3  woman       False    C  Southampton   yes  False   63.1000
# 4    man        True  NaN  Southampton    no   True   18.0500

# %%
df.drop('new_fare',axis=1)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.loc[len(df.index)]=[1,0,3,'34',32.0,0,0,7.7500,'Q','Third','man','True','yes','Queenstown','no','True']

# %%
df.tail()
# Out:
#      survived  pclass   sex   age  sibsp  parch   fare embarked  class    who  \
# 889         1       1  male  26.0    0.0      0  30.00        C  First    man
# 890         0       3  male  32.0    0.0      0   7.75        Q  Third    man
# 891       892       0     3  male   32.0      0   0.00     7.75      Q  Third
# 892         1       0     3  male   32.0      0   0.00     7.75      Q  Third
# 893         1       0     3    34   32.0      0   0.00     7.75      Q  Third
#
#     adult_male  deck embark_town       alive alone new_fare
# 889       True     C   Cherbourg         yes  True     40.0
# 890       True   NaN  Queenstown          no  True    17.75
# 891        man  True         yes  Queenstown    no     True
# 892        man  True         yes  Queenstown    no     True
# 893        man  True         yes  Queenstown    no     True

# %%
df=pd.read_csv("C:/Users/mehta/Desktop/AIML Study Materials/AIML-20CS51I/DataSets/titanic.csv")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['age'].plot(kind='box')
# Out:
# <Axes: >

# %%
q1=df['age'].quantile(0.25)
q3=df['age'].quantile(0.75)
iqr=q3-q1
upper_bound=q3+(1.5*iqr)
lower_bound=q1-(1.5*iqr)
arr_sibsp=df['age']
upper_cap=60
lower_cap=0
for i in df['age']:
    if i<lower_bound:
        df['age']=df['age'].replace(i,lower_cap)
    elif i>upper_bound:
        df['age']=df['age'].replace(i,upper_cap)

df['age'].plot(kind='box')
# Out:
# <Axes: >
